# %%
# !python3 -m pip install paddlepaddle-gpu==3.0.0b1 -i https://www.paddlepaddle.org.cn/packages/stable/cu123/
# !pip install "paddleocr>=2.8.1"
# Out:
# Looking in indexes: https://www.paddlepaddle.org.cn/packages/stable/cu123/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.9/888.9 MB 1.7 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.7/867.7 kB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 12.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.9/669.9 MB 1.5 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.6/412.6 MB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.1 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !python3 "/kaggle/input/cv-project-files2/PaddleOCR-main/PaddleOCR-main/tools/train.py" -c "/kaggle/input/cv-project-files2/en_PP-OCRv3_rec_k.yml"
# Out:
# [2024/12/11 16:24:13] ppocr INFO: Architecture :
# [2024/12/11 16:24:13] ppocr INFO:     Backbone :
# [2024/12/11 16:24:13] ppocr INFO:         last_conv_stride : [1, 2]
# [2024/12/11 16:24:13] ppocr INFO:         last_pool_type : avg
# [2024/12/11 16:24:13] ppocr INFO:         name : MobileNetV1Enhance
# [2024/12/11 16:24:13] ppocr INFO:         scale : 0.5
# [2024/12/11 16:24:13] ppocr INFO:     Head :
# [2024/12/11 16:24:13] ppocr INFO:         head_list :
# [2024/12/11 16:24:13] ppocr INFO:             CTCHead :
# [2024/12/11 16:24:13] ppocr INFO:                 Head :
# [2024/12/11 16:24:13] ppocr INFO:                     fc_decay : 1e-05
# [2024/12/11 16:24:13] ppocr INFO:                 Neck :
# [2024/12/11 16:24:13] ppocr INFO:                     depth : 2
# [2024/12/11 16:24:13] ppocr INFO:                     dims : 64
# [2024/12/11 16:24:13] ppocr INFO:                     hidden_dims : 120
# [2024/12/11 16:24:13] ppocr INFO:                     name : svtr
# ...
